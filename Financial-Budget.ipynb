# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"India_budget_2021.csv")

# %%
data
# Out:
#                                  Department /Ministry  \
# 0                             MINISTRY OF AGRICULTURE
# 1                         DEPARTMENT OF ATOMIC ENERGY
# 2                          MINISTRY OF AYURVEDA, YOGA
# 3                MINISTRY OF CHEMICALS AND FERTILISER
# 4                          MINISTRY OF CIVIL AVIATION
# 5                                    MINISTRY OF COAL
# 6                   MINISTRY OF COMMERCE AND INDUSTRY
# 7                           MINISTRY OF COMMUNICATION
# 8                        MINISTRY OF CONSUMER AFFAIRS
# 9                       MINISTRY OF CORPORATE AFFAIRS
# 10                                MINISTRY OF CULTURE
# 11                                MINISTRY OF DEFENCE
# 12    MINISTRY OF DEVELOPMENT OF NORTH EASTERN REGION
# 13                         MINISTRY OF EARTH SCIENCES
# 14                              MINISTRY OF EDUCATION
# 15  MINISTRY OF ELECTRONICS AND INFORMATION TECHNO...
# ...

# %%
data.shape
# Out:
# (57, 2)

# %%
data.isna().sum()
# Out:
# Department /Ministry         1
# Fund allotted(in ₹crores)    1
# dtype: int64

# %%
data = data.dropna()
data
# Out:
#                                  Department /Ministry  \
# 0                             MINISTRY OF AGRICULTURE
# 1                         DEPARTMENT OF ATOMIC ENERGY
# 2                          MINISTRY OF AYURVEDA, YOGA
# 3                MINISTRY OF CHEMICALS AND FERTILISER
# 4                          MINISTRY OF CIVIL AVIATION
# 5                                    MINISTRY OF COAL
# 6                   MINISTRY OF COMMERCE AND INDUSTRY
# 7                           MINISTRY OF COMMUNICATION
# 8                        MINISTRY OF CONSUMER AFFAIRS
# 9                       MINISTRY OF CORPORATE AFFAIRS
# 10                                MINISTRY OF CULTURE
# 11                                MINISTRY OF DEFENCE
# 12    MINISTRY OF DEVELOPMENT OF NORTH EASTERN REGION
# 13                         MINISTRY OF EARTH SCIENCES
# 14                              MINISTRY OF EDUCATION
# 15  MINISTRY OF ELECTRONICS AND INFORMATION TECHNO...
# ...

# %%
data.isna().sum()
# Out:
# Department /Ministry         0
# Fund allotted(in ₹crores)    0
# dtype: int64

# %% [markdown]
# # Which Ministry has highest Budget Allocation

# %%
plt.figure(figsize=(18,8))
sns.barplot(data=data,x="Department /Ministry",y="Fund allotted(in ₹crores)",palette="viridis")
plt.xticks(rotation=90)
plt.title("Graph Between Fund Allocated And Department / Ministry")
plt.show()
# Out:
# C:\Users\Sufi Computers\AppData\Local\Temp\ipykernel_14124\2442391943.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data,x="Department /Ministry",y="Fund allotted(in ₹crores)",palette="viridis")

# %%
data=data.iloc[:-1 , :]
data
# Out:
#                                  Department /Ministry  \
# 0                             MINISTRY OF AGRICULTURE
# 1                         DEPARTMENT OF ATOMIC ENERGY
# 2                          MINISTRY OF AYURVEDA, YOGA
# 3                MINISTRY OF CHEMICALS AND FERTILISER
# 4                          MINISTRY OF CIVIL AVIATION
# 5                                    MINISTRY OF COAL
# 6                   MINISTRY OF COMMERCE AND INDUSTRY
# 7                           MINISTRY OF COMMUNICATION
# 8                        MINISTRY OF CONSUMER AFFAIRS
# 9                       MINISTRY OF CORPORATE AFFAIRS
# 10                                MINISTRY OF CULTURE
# 11                                MINISTRY OF DEFENCE
# 12    MINISTRY OF DEVELOPMENT OF NORTH EASTERN REGION
# 13                         MINISTRY OF EARTH SCIENCES
# 14                              MINISTRY OF EDUCATION
# 15  MINISTRY OF ELECTRONICS AND INFORMATION TECHNO...
# ...

# %%
plt.figure(figsize=(18,8))
sns.barplot(data,x='Department /Ministry',y='Fund allotted(in ₹crores)',palette="spring")
plt.xticks(rotation=90)
# plt.xlabel(fontsize=10)
plt.title("Graph Between Fund Allocated And Department / Ministry",fontsize=20,weight="bold")
plt.show()
# Out:
# C:\Users\Sufi Computers\AppData\Local\Temp\ipykernel_14124\3600364243.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data,x='Department /Ministry',y='Fund allotted(in ₹crores)',palette="spring")

# %% [markdown]
# # Distribution of Budget For Top 10 Ministries

# %%
data = data.sort_values(by='Fund allotted(in ₹crores)',ascending=False)
data.head(10)
# Out:
#                       Department /Ministry  Fund allotted(in ₹crores)
# 18                     MINISTRY OF FINANCE                 1386273.30
# 11                     MINISTRY OF DEFENCE                  478195.62
# 8             MINISTRY OF CONSUMER AFFAIRS                  256948.40
# 23                MINISTRY OF HOME AFFAIRS                  166546.94
# 43           MINISTRY OF RURAL DEVELOPMENT                  133689.50
# 0                  MINISTRY OF AGRICULTURE                  131531.19
# 42  MINISTRY OF ROAD TRANSPORT AND HIGHWAY                  118101.00
# 41                    MINISTRY OF RAILWAYS                  110054.64
# 14                   MINISTRY OF EDUCATION                   93224.31
# 3     MINISTRY OF CHEMICALS AND FERTILISER                   80714.94

# %%
new_data = data.head(10)
df = new_data["Fund allotted(in ₹crores)"]
labels=new_data['Department /Ministry']
plt.figure(figsize=(8,7))
plt.pie(df,labels=labels,autopct="%1.1f%%",startangle=45,pctdistance=0.7,shadow=True)
central_circle = plt.Circle((0,0),0.5,color="white")
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font',size=12)
plt.title("Distribution of Budget in Top 10 Ministries",weight="bold")
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.barplot(data,x='Department /Ministry',y='Fund allotted(in ₹crores)',palette="hot")
plt.xticks(rotation=90)

plt.title("Distribution of Budget in Top 10 Ministries",fontsize=20,weight="bold")
plt.show()
# Out:
# C:\Users\Sufi Computers\AppData\Local\Temp\ipykernel_14124\2615520354.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data,x='Department /Ministry',y='Fund allotted(in ₹crores)',palette="hot")

# %% [markdown]
# # Distriution of Budget For Last 10 Ministries

# %%
data = data.sort_values(by='Fund allotted(in ₹crores)',ascending=True)
data.head(10)
# Out:
#                       Department /Ministry  Fund allotted(in ₹crores)
# 49                       MINISTRY OF STEEL                      39.25
# 34       MINISTRY OF PARLIAMENTARY AFFAIRS                      65.07
# 5                         MINISTRY OF COAL                     534.88
# 9            MINISTRY OF CORPORATE AFFAIRS                     712.13
# 33              MINISTRY OF PANCHAYATI RAJ                     913.43
# 22            MINISTRY OF HEAVY INDUSTRIES                    1017.08
# 37                    MINISTRY OF PLANNING                    1062.77
# 20  MINISTRY OF FOOD PROCESSING INDUSTRIES                    1308.66
# 48                  MINISTRY OF STATISTICS                    1409.13
# 30                       MINISTRY OF MINES                    1466.82

# %%
new_data = data.head(10)
df = new_data["Fund allotted(in ₹crores)"]
labels=new_data['Department /Ministry']
plt.figure(figsize=(8,7))
plt.pie(df,labels=labels,autopct="%1.1f%%",startangle=0,pctdistance=0.7,shadow=True)
central_circle = plt.Circle((0,0),0.8,color="white")
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font',size=12)
plt.title("Distribution of Budget in Last 10 Ministries",weight="bold")
plt.show()

# %%
plt.figure(figsize=(18,8))
sns.barplot(data,x='Department /Ministry',y='Fund allotted(in ₹crores)',palette="spring")
plt.xticks(rotation=90)

plt.title("Distribution of Budget in Last 10 Ministries",fontsize=20,weight="bold")
plt.show()
# Out:
# C:\Users\Sufi Computers\AppData\Local\Temp\ipykernel_14124\1346454684.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data,x='Department /Ministry',y='Fund allotted(in ₹crores)',palette="spring")

# %% [markdown]
# # We can Also place it Between last 10 ministries

# %%
plt.figure(figsize=(18,8))
sns.barplot(new_data,x='Department /Ministry',y='Fund allotted(in ₹crores)',palette="viridis",width=0.4)
plt.xticks(rotation=90)

plt.title("Distribution of Budget in Last 10 Ministries",fontsize=20,weight="bold")
plt.show()
# Out:
# C:\Users\Sufi Computers\AppData\Local\Temp\ipykernel_14124\2237933630.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(new_data,x='Department /Ministry',y='Fund allotted(in ₹crores)',palette="viridis",width=0.4)
